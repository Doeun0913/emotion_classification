# %%
import pandas as pd

# 데이터 불러오기 (예: df = pd.read_csv('your_file.csv'))
# df = pd.read_csv('your_file.csv')

# '_std'로 끝나는 컬럼 목록 추출
std_columns = [col for col in df.columns if col.endswith('_std')]

# '_range'로 끝나는 컬럼 목록 추출
range_columns = [col for col in df.columns if col.endswith('_range')]

# '_std' 컬럼들의 합 계산하여 새로운 컬럼 추가
df['std_sum'] = df[std_columns].sum(axis=1)

# '_range' 컬럼들의 합 계산하여 새로운 컬럼 추가
df['range_sum'] = df[range_columns].sum(axis=1)

# %%
df.head()
# Out:
#    Unnamed: 0                                               text  labels  \
# 0           0  Car-free cities have become a subject of incre...       1
# 1           1  Car Free Cities  Car-free cities, a concept ga...       1
# 2           2    A Sustainable Urban Future  Car-free cities ...       1
# 3           3    Pioneering Sustainable Urban Living  In an e...       1
# 4           4    The Path to Sustainable Urban Living  In an ...       1
#
#   category                                         admiration  \
# 0    essay  [0.006202359218150377, 0.005537346471101046, 0...
# 1    essay  [0.008527817204594612, 0.0032891768496483564, ...
# 2    essay  [0.012623267248272896, 0.018976466730237007, 0...
# 3    essay  [0.08386484533548355, 0.002318307990208268, 0....
# 4    essay  [0.027907034382224083, 0.010891354642808437, 0...
#
#                                            amusement  \
# 0  [0.0016371539095416665, 0.0005263797356747091,...
# ...

# %%
import pandas as pd

df1 = pd.read_csv("essay3_features.csv")

df2 = pd.read_csv("movie3_features.csv")

df3 = pd.read_csv("explanation3_features.csv")

df4 = pd.read_csv("book3_features.csv")

df5 = pd.read_csv("hc3_features.csv")

df6 = pd.read_csv("food3_features.csv")

df7 = pd.read_csv("dialog3.csv")

# %% [markdown]
# ## info

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27182 entries, 0 to 27181
# Data columns (total 93 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   text                   27182 non-null  object
#  1   labels                 27182 non-null  int64
#  2   category               27182 non-null  object
#  3   admiration             27182 non-null  object
#  4   amusement              27182 non-null  object
#  5   anger                  27182 non-null  object
#  6   annoyance              27182 non-null  object
#  7   approval               27182 non-null  object
#  8   caring                 27182 non-null  object
#  9   confusion              27182 non-null  object
#  10  curiosity              27182 non-null  object
#  11  desire                 27182 non-null  object
#  12  disappointment         27182 non-null  object
#  13  disapproval            27182 non-null  object
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52532 entries, 0 to 52531
# Data columns (total 93 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   text                   52532 non-null  object
#  1   labels                 52532 non-null  int64
#  2   category               52532 non-null  object
#  3   admiration             52532 non-null  object
#  4   amusement              52532 non-null  object
#  5   anger                  52532 non-null  object
#  6   annoyance              52532 non-null  object
#  7   approval               52532 non-null  object
#  8   caring                 52532 non-null  object
#  9   confusion              52532 non-null  object
#  10  curiosity              52532 non-null  object
#  11  desire                 52532 non-null  object
#  12  disappointment         52532 non-null  object
#  13  disapproval            52532 non-null  object
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5789 entries, 0 to 5788
# Data columns (total 93 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   text                   5789 non-null   object
#  1   labels                 5789 non-null   int64
#  2   category               5789 non-null   object
#  3   admiration             5789 non-null   object
#  4   amusement              5789 non-null   object
#  5   anger                  5789 non-null   object
#  6   annoyance              5789 non-null   object
#  7   approval               5789 non-null   object
#  8   caring                 5789 non-null   object
#  9   confusion              5789 non-null   object
#  10  curiosity              5789 non-null   object
#  11  desire                 5789 non-null   object
#  12  disappointment         5789 non-null   object
#  13  disapproval            5789 non-null   object
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51763 entries, 0 to 51762
# Data columns (total 93 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   text                   51763 non-null  object
#  1   labels                 51763 non-null  int64
#  2   category               51763 non-null  object
#  3   admiration             51763 non-null  object
#  4   amusement              51763 non-null  object
#  5   anger                  51763 non-null  object
#  6   annoyance              51763 non-null  object
#  7   approval               51763 non-null  object
#  8   caring                 51763 non-null  object
#  9   confusion              51763 non-null  object
#  10  curiosity              51763 non-null  object
#  11  desire                 51763 non-null  object
#  12  disappointment         51763 non-null  object
#  13  disapproval            51763 non-null  object
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43131 entries, 0 to 43130
# Data columns (total 93 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   text                   43131 non-null  object
#  1   labels                 43131 non-null  int64
#  2   category               43131 non-null  object
#  3   admiration             43131 non-null  object
#  4   amusement              43131 non-null  object
#  5   anger                  43131 non-null  object
#  6   annoyance              43131 non-null  object
#  7   approval               43131 non-null  object
#  8   caring                 43131 non-null  object
#  9   confusion              43131 non-null  object
#  10  curiosity              43131 non-null  object
#  11  desire                 43131 non-null  object
#  12  disappointment         43131 non-null  object
#  13  disapproval            43131 non-null  object
# ...

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19454 entries, 0 to 19453
# Data columns (total 93 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   text                   19454 non-null  object
#  1   labels                 19454 non-null  int64
#  2   admiration             19454 non-null  object
#  3   amusement              19454 non-null  object
#  4   anger                  19454 non-null  object
#  5   annoyance              19454 non-null  object
#  6   approval               19454 non-null  object
#  7   caring                 19454 non-null  object
#  8   confusion              19454 non-null  object
#  9   curiosity              19454 non-null  object
#  10  desire                 19454 non-null  object
#  11  disappointment         19454 non-null  object
#  12  disapproval            19454 non-null  object
#  13  disgust                19454 non-null  object
# ...

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57324 entries, 0 to 57323
# Data columns (total 93 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   text                   57324 non-null  object
#  1   labels                 57324 non-null  int64
#  2   category               57324 non-null  object
#  3   admiration             57324 non-null  object
#  4   amusement              57324 non-null  object
#  5   anger                  57324 non-null  object
#  6   annoyance              57324 non-null  object
#  7   approval               57324 non-null  object
#  8   caring                 57324 non-null  object
#  9   confusion              57324 non-null  object
#  10  curiosity              57324 non-null  object
#  11  desire                 57324 non-null  object
#  12  disappointment         57324 non-null  object
#  13  disapproval            57324 non-null  object
# ...

# %%
# prompt: df6 'category'컬럼제거후 3열에 'category'컬럼 추가후 'review'로 값넣기

# drop the existing 'category' column if it exists
if 'category' in df6.columns:
    df6 = df6.drop('category', axis=1)

# insert a new 'category' column at index 2 (3rd column) with value 'review'
df6.insert(2, 'category', 'review')

df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19454 entries, 0 to 19453
# Data columns (total 93 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   text                   19454 non-null  object
#  1   labels                 19454 non-null  int64
#  2   category               19454 non-null  object
#  3   admiration             19454 non-null  object
#  4   amusement              19454 non-null  object
#  5   anger                  19454 non-null  object
#  6   annoyance              19454 non-null  object
#  7   approval               19454 non-null  object
#  8   caring                 19454 non-null  object
#  9   confusion              19454 non-null  object
#  10  curiosity              19454 non-null  object
#  11  desire                 19454 non-null  object
#  12  disappointment         19454 non-null  object
#  13  disapproval            19454 non-null  object
# ...

# %% [markdown]
# ## 결측치 제거

# %%
# prompt: df1 결측치 제거

df1 = df1.dropna()
df2 = df2.dropna()
df3 = df3.dropna()
df4 = df4.dropna()
df5 = df5.dropna()
df6 = df6.dropna()

# %%
# prompt: df info

df1.info()
df2.info()
df3.info()
df4.info()
df5.info()
df6.info()
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27181 entries, 0 to 27181
# Data columns (total 93 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   text                   27181 non-null  object
#  1   labels                 27181 non-null  int64
#  2   category               27181 non-null  object
#  3   admiration             27181 non-null  object
#  4   amusement              27181 non-null  object
#  5   anger                  27181 non-null  object
#  6   annoyance              27181 non-null  object
#  7   approval               27181 non-null  object
#  8   caring                 27181 non-null  object
#  9   confusion              27181 non-null  object
#  10  curiosity              27181 non-null  object
#  11  desire                 27181 non-null  object
#  12  disappointment         27181 non-null  object
#  13  disapproval            27181 non-null  object
# ...

# %% [markdown]
# ## valuecount

# %%
# prompt: df labels별 valuecount

print(df1['labels'].value_counts())
print(df2['labels'].value_counts())
print(df3['labels'].value_counts())
print(df4['labels'].value_counts())
print(df5['labels'].value_counts())
print(df6['labels'].value_counts())
print(df7['labels'].value_counts())
# Out:
# labels
# 0    16004
# 1    11177
# Name: count, dtype: int64
# labels
# 0    47509
# 1     5023
# Name: count, dtype: int64
# labels
# 0    3341
# 1    2441
# Name: count, dtype: int64
# labels
# 0    26084
# 1    25173
# Name: count, dtype: int64
# labels
# 1    22950
# 0    19987
# Name: count, dtype: int64
# labels
# 1    9824
# 0    9607
# Name: count, dtype: int64
# labels
# 1    47234
# 0    10090
# Name: count, dtype: int64

# %%
# prompt: labels=0 의 합계를 구하는 코드

label_0_sum = (df1['labels'].value_counts()[0] +
               df2['labels'].value_counts()[0] +
               df3['labels'].value_counts()[0] +
               df4['labels'].value_counts()[0] +
               df5['labels'].value_counts()[0] +
               df6['labels'].value_counts()[0] +
               df7['labels'].value_counts()[0] )

label_1_sum = (df1['labels'].value_counts()[1] +
               df2['labels'].value_counts()[1] +
               df3['labels'].value_counts()[1] +
               df4['labels'].value_counts()[1] +
               df5['labels'].value_counts()[1] +
               df6['labels'].value_counts()[1] +
               df7['labels'].value_counts()[1] )

print("0:", label_0_sum)
print("1:", label_1_sum)
print("총:", label_0_sum+label_1_sum)
# Out:
# 0: 132622
# 1: 123822
# 총: 256444

# %% [markdown]
# ## 모두 합치기

# %%
# prompt: df 모두 합치기

import pandas as pd
df_combined = pd.concat([df1, df2, df3, df4, df5, df6, df7], ignore_index=True)

df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256444 entries, 0 to 256443
# Data columns (total 93 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   text                   256444 non-null  object
#  1   labels                 256444 non-null  int64
#  2   category               256444 non-null  object
#  3   admiration             256444 non-null  object
#  4   amusement              256444 non-null  object
#  5   anger                  256444 non-null  object
#  6   annoyance              256444 non-null  object
#  7   approval               256444 non-null  object
#  8   caring                 256444 non-null  object
#  9   confusion              256444 non-null  object
#  10  curiosity              256444 non-null  object
#  11  desire                 256444 non-null  object
#  12  disappointment         256444 non-null  object
#  13  disapproval            256444 non-null  object
# ...

# %%
df_combined.to_csv('combined_fianl.csv', index=True)

# %%
# prompt: df_combined labels valuecount

print(df_combined['labels'].value_counts())
# Out:
# labels
# 0    132622
# 1    123822
# Name: count, dtype: int64

# %%
# prompt: df_combined category value count

print(df_combined['category'].value_counts())
# Out:
# category
# review         123220
# dialog          57324
# hc3             42937
# essay           27181
# explanation      5782
# Name: count, dtype: int64

# %%
# prompt: df_combined main_emotion valuecount

df_combined['main_emotion'].value_counts()
# Out:
# main_emotion
# neutral           205614
# admiration         32260
# approval            6671
# love                2875
# joy                 2057
# disappointment      1597
# caring               898
# amusement            848
# disapproval          704
# annoyance            422
# gratitude            394
# sadness              379
# curiosity            305
# confusion            278
# optimism             254
# excitement           198
# fear                 140
# disgust              135
# surprise             129
# desire               127
# realization           86
# remorse               34
# anger                 29
# embarrassment          7
# nervousness            3
# Name: count, dtype: int64

# %% [markdown]
# ## 모델 테스트

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report

# 데이터 불러오기
df = pd.read_csv("plus_feature_file_cleaned.csv.csv")

# 피처 선택
std_cols = [col for col in df.columns if col.endswith('_std')]
range_cols = [col for col in df.columns if col.endswith('_range')]
other_cols = ["mean_emotion_diff", "dominant_change_count",
              "emotion_entropy", "pos_neg_ratio", "polarity_switches"]

feature_cols = std_cols + range_cols + other_cols

X = df[feature_cols]
y = df["labels"]

# 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# XGBoost 분류기
model = XGBClassifier(
    use_label_encoder=False,
    eval_metric='mlogloss',  # 다중 클래스 분류일 경우
    random_state=100
)
model.fit(X_train, y_train)

# 예측
y_pred = model.predict(X_test)

# 평가 지표 출력
print("✅ Accuracy:", accuracy_score(y_test, y_pred))
print("✅ Precision (macro):", precision_score(y_test, y_pred, average='macro'))
print("✅ Recall    (macro):", recall_score(y_test, y_pred, average='macro'))
print("✅ F1 Score  (macro):", f1_score(y_test, y_pred, average='macro'))

print(classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [09:55:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ✅ Accuracy: 0.8454639396361793
# ✅ Precision (macro): 0.8458462233848552
# ✅ Recall    (macro): 0.844660432179687
# ✅ F1 Score  (macro): 0.8450303310937247
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85     26586
#            1       0.85      0.82      0.84     24703
#
#     accuracy                           0.85     51289
#    macro avg       0.85      0.84      0.85     51289
# weighted avg       0.85      0.85      0.85     51289

# %% [markdown]
# ## 하이퍼파라미터튜닝진행

# %%
# prompt: google drive 에서 파일 불러오기
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

# Mount your Google Drive and replace 'YourFileName.csv' with the actual file path in your Drive

# 데이터 불러오기
# Replace 'combined_data.csv' with the path where you saved the combined file in your Drive
df = pd.read_csv("/content/drive/MyDrive/combined_data.csv")
dialog = pd.read_csv("/content/drive/MyDrive/dialog_sj_final.csv")
# Out:
# Mounted at /content/drive

# %%
dialog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36075 entries, 0 to 36074
# Data columns (total 93 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   text                   36075 non-null  object
#  1   labels                 36075 non-null  int64
#  2   category               36075 non-null  object
#  3   admiration             36075 non-null  object
#  4   amusement              36075 non-null  object
#  5   anger                  36075 non-null  object
#  6   annoyance              36075 non-null  object
#  7   approval               36075 non-null  object
#  8   caring                 36075 non-null  object
#  9   confusion              36075 non-null  object
#  10  curiosity              36075 non-null  object
#  11  desire                 36075 non-null  object
#  12  disappointment         36075 non-null  object
#  13  disapproval            36075 non-null  object
# ...

# %%
import pandas as pd
df_combined = pd.concat([df, dialog], ignore_index=True)

df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292519 entries, 0 to 292518
# Data columns (total 94 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             256444 non-null  float64
#  1   text                   292519 non-null  object
#  2   labels                 292519 non-null  int64
#  3   category               292519 non-null  object
#  4   admiration             292519 non-null  object
#  5   amusement              292519 non-null  object
#  6   anger                  292519 non-null  object
#  7   annoyance              292519 non-null  object
#  8   approval               292519 non-null  object
#  9   caring                 292519 non-null  object
#  10  confusion              292519 non-null  object
#  11  curiosity              292519 non-null  object
#  12  desire                 292519 non-null  object
#  13  disappointment         292519 non-null  object
# ...

# %%
# !pip install xgboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.9/253.9 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.4/322.4 MB 3.3 MB/s eta 0:00:00
# ...

# %%
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
import pandas as pd

# 데이터 준비 (이전 코드와 동일)
#df = pd.read_csv("plus_feature_file_cleaned.csv.csv")

std_cols = [col for col in df.columns if col.endswith('_std')]
range_cols = [col for col in df.columns if col.endswith('_range')]
other_cols = ["mean_emotion_diff", "dominant_change_count", "emotion_entropy", "pos_neg_ratio", "polarity_switches"]

X = df[std_cols + range_cols + other_cols]
y = df["labels"]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# XGBoost 기본 모델
xgb = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)

# 하이퍼파라미터 그리드
param_dist = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7, 9],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'gamma': [0, 0.1, 0.5, 1],
    'min_child_weight': [1, 3, 5],
    'reg_alpha': [0, 0.1, 0.5],
    'reg_lambda': [1, 1.5, 2]
}

# RandomizedSearchCV 수행
random_search = RandomizedSearchCV(
    estimator=xgb,
    param_distributions=param_dist,
    n_iter=30,
    scoring='f1_macro',  # 다중 클래스에서 macro F1 score 최적화
    cv=3,
    verbose=2,
    random_state=42,
    n_jobs=-1
)

random_search.fit(X_train, y_train)

# 최적 모델로 예측
best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test)

# 성능 평가
print("Best Parameters:\n", random_search.best_params_)
print("\n📊 최적 모델 성능:\n")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-3669482227> in <cell line: 0>()
#      45 )
#      46
# ---> 47 random_search.fit(X_train, y_train)
#      48
#      49 # 최적 모델로 예측
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, **params)
#    1022                 return results
#    1023
# -> 1024             self._run_search(evaluate_candidates)
#    1025
#    1026             # multimetric is determined here because in the case of a callable
#
# ...

# %%
from xgboost import plot_importance
plot_importance(best_model, max_num_features=20)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Importance score', ylabel='Features'>

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d')
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
# 예측과 실제 불일치한 데이터 추출
error_df = X_test.copy()
error_df['true_label'] = y_test.values
error_df['predicted'] = y_pred
misclassified = error_df[error_df['true_label'] != error_df['predicted']]

# %%
# prompt: df의 category=review인 행에서 labels=0인것 랜덤으로 40000개 삭제후 저장
df= df_combined
# 'category'가 'review'이고 'labels'가 0인 행 필터링
review_0_rows = df[(df['category'] == 'review') & (df['labels'] == 0)]

# 삭제할 행의 개수 설정
n_samples_to_drop = 40000

# 삭제할 행이 충분히 있는지 확인
if len(review_0_rows) > n_samples_to_drop:
    # 랜덤으로 40000개의 인덱스 선택
    indices_to_drop = review_0_rows.sample(n=n_samples_to_drop, random_state=42).index

    # 해당 인덱스의 행 삭제
    df_combined_filtered = df.drop(indices_to_drop)
    print(f"{n_samples_to_drop}개의 'review' 카테고리 중 label이 0인 행을 삭제했습니다.")
else:
    df_combined_filtered = df.copy()
    print("'review' 카테고리 중 label이 0인 행이 40000개보다 적어서 삭제하지 않았습니다.")

# 결과 확인
print("삭제 후 df_combined_filtered 정보:")
df_combined_filtered.info()
print("\n삭제 후 'review' 카테고리 중 label=0 개수:")
print(df_combined_filtered[(df_combined_filtered['category'] == 'review') & (df_combined_filtered['labels'] == 0)]['labels'].value_counts())
print("\n삭제 후 전체 'labels' value_counts:")
print(df_combined_filtered['labels'].value_counts())
print("\n삭제 후 전체 'category' value_counts:")
print(df_combined_filtered['category'].value_counts())

# 필터링된 데이터프레임을 새로운 CSV 파일로 저장
df_combined_filtered.to_csv('/content/drive/MyDrive/combined_data_filtered_fianl.csv', index=False)
print("\n필터링된 데이터가 'combined_data_filtered.csv' 파일로 저장되었습니다.")
# Out:
# 40000개의 'review' 카테고리 중 label이 0인 행을 삭제했습니다.
# 삭제 후 df_combined_filtered 정보:
# <class 'pandas.core.frame.DataFrame'>
# Index: 252519 entries, 0 to 292518
# Data columns (total 94 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             216444 non-null  float64
#  1   text                   252519 non-null  object
#  2   labels                 252519 non-null  int64
#  3   category               252519 non-null  object
#  4   admiration             252519 non-null  object
#  5   amusement              252519 non-null  object
#  6   anger                  252519 non-null  object
#  7   annoyance              252519 non-null  object
#  8   approval               252519 non-null  object
#  9   caring                 252519 non-null  object
#  10  confusion              252519 non-null  object
#  11  curiosity              252519 non-null  object
#  12  desire                 252519 non-null  object
# ...

# %%
df_combined_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 252519 entries, 0 to 292518
# Data columns (total 94 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             216444 non-null  float64
#  1   text                   252519 non-null  object
#  2   labels                 252519 non-null  int64
#  3   category               252519 non-null  object
#  4   admiration             252519 non-null  object
#  5   amusement              252519 non-null  object
#  6   anger                  252519 non-null  object
#  7   annoyance              252519 non-null  object
#  8   approval               252519 non-null  object
#  9   caring                 252519 non-null  object
#  10  confusion              252519 non-null  object
#  11  curiosity              252519 non-null  object
#  12  desire                 252519 non-null  object
#  13  disappointment         252519 non-null  object
# ...

# %%
print(df_combined_filtered['category'].value_counts())
print(df_combined_filtered['labels'].value_counts())

category_labels_counts2 = df_combined_filtered.groupby('category')['labels'].value_counts()
print("\n카테고리별 labels value counts + dialog:")
category_labels_counts2
# Out:
# category
# review         83220
# dialog         82854
# hc3            42937
# essay          27181
# 대화문            10545
# explanation     5782
# Name: count, dtype: int64
# labels
# 0    128697
# 1    123822
# Name: count, dtype: int64
#
# 카테고리별 labels value counts + dialog:
# category     labels
# dialog       1         47234
#              0         35620
# essay        0         16004
#              1         11177
# explanation  0          3341
#              1          2441
# hc3          1         22950
#              0         19987
# review       0         43200
#              1         40020
# 대화문          0         10545
# Name: count, dtype: int64

# %% [markdown]
# ## 리뷰 개수 맞추기

# %%
df = pd.read_csv("combined_fianl.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292519 entries, 0 to 292518
# Data columns (total 95 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0.1           292519 non-null  int64
#  1   Unnamed: 0             256444 non-null  float64
#  2   text                   292519 non-null  object
#  3   labels                 292519 non-null  int64
#  4   category               292519 non-null  object
#  5   admiration             292519 non-null  object
#  6   amusement              292519 non-null  object
#  7   anger                  292519 non-null  object
#  8   annoyance              292519 non-null  object
#  9   approval               292519 non-null  object
#  10  caring                 292519 non-null  object
#  11  confusion              292519 non-null  object
#  12  curiosity              292519 non-null  object
#  13  desire                 292519 non-null  object
# ...

# %%
print(df['category'].value_counts())
print(df['labels'].value_counts())

category_labels_counts2 = df.groupby('category')['labels'].value_counts()
print("\n카테고리별 labels value counts + dialog:")
category_labels_counts2
# Out:
# category
# review         123220
# dialog          82854
# hc3             42937
# essay           27181
# 대화문             10545
# explanation      5782
# Name: count, dtype: int64
# labels
# 0    168697
# 1    123822
# Name: count, dtype: int64
#
# 카테고리별 labels value counts + dialog:
# category     labels
# dialog       1         47234
#              0         35620
# essay        0         16004
#              1         11177
# explanation  0          3341
#              1          2441
# hc3          1         22950
#              0         19987
# review       0         83200
#              1         40020
# 대화문          0         10545
# Name: count, dtype: int64

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report

import pandas as pd

# 데이터 준비
df = pd.read_csv("/content/drive/MyDrive/combined_data.csv")
std_cols = [col for col in df.columns if col.endswith('_std')]
range_cols = [col for col in df.columns if col.endswith('_range')]
other_cols = ["mean_emotion_diff", "dominant_change_count", "emotion_entropy", "pos_neg_ratio", "polarity_switches"]

X = df[std_cols + range_cols + other_cols]
y = df["labels"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=100)

# ✅ 베스트 파라미터 적용 모델
best_xgb = XGBClassifier(
    subsample=0.8,
    reg_lambda=1,
    reg_alpha=0.5,
    n_estimators=300,
    min_child_weight=3,
    max_depth=9,
    learning_rate=0.1,
    gamma=0.1,
    colsample_bytree=1.0,
    use_label_encoder=False,
    eval_metric='mlogloss',
    random_state=42
)

# 학습
best_xgb.fit(X_train, y_train)

# 예측
y_pred = best_xgb.predict(X_test)

# 성능 평가
print("\n📌 적용된 베스트 파라미터:")
print(best_xgb.get_params())

print("\n📊 모델 성능 평가:")
print(classification_report(y_test, y_pred))

# 정확도 출력
print("Accuracy :", accuracy_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))

#dialog 다 넣기전- 리뷰맞추지않음
# Accuracy : 0.8582179762136869
# F1 Score : 0.8508980562617896
# Precision: 0.8679829331548565
# Recall   : 0.8344727740690099

#dialog 다 넣기전- 리뷰맞춤
# Accuracy : 0.8632940632940633
# F1 Score : 0.8813600096227096
# Precision: 0.8728557814485387
# Recall   : 0.8900315815045753

#dialog 다 넣은후 - 리뷰맞춤
# Accuracy : 0.876643434183431
# F1 Score : 0.873255482768442
# Precision: 0.8760715160421259
# Recall   : 0.8704574951330305

#dialog 다 넣은후 - review맞추지 않음
# Accuracy : 0.8772391631341446
# F1 Score : 0.8516054382412497
# Precision: 0.8752229678076956
# Recall   : 0.8292290358924835
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/training.py:183: UserWarning: [11:28:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# 📌 적용된 베스트 파라미터:
# ...

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
# 예측 수행
y_pred = best_xgb.predict(X_test)

# 잘못 예측한 인덱스 찾기
misclassified_indices = X_test.index[y_test != y_pred]
# 원본 df에서 잘못 예측한 샘플만 추출
misclassified_df = df.loc[misclassified_indices].copy()

# 실제 label과 예측 label 컬럼 추가
misclassified_df["true_label"] = y_test.loc[misclassified_indices].values
misclassified_df["predicted_label"] = y_pred[y_test != y_pred]
misclassified_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2959 entries, 82089 to 124435
# Data columns (total 96 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             2959 non-null   int64
#  1   text                   2959 non-null   object
#  2   labels                 2959 non-null   int64
#  3   category               2959 non-null   object
#  4   admiration             2959 non-null   object
#  5   amusement              2959 non-null   object
#  6   anger                  2959 non-null   object
#  7   annoyance              2959 non-null   object
#  8   approval               2959 non-null   object
#  9   caring                 2959 non-null   object
#  10  confusion              2959 non-null   object
#  11  curiosity              2959 non-null   object
#  12  desire                 2959 non-null   object
#  13  disappointment         2959 non-null   object
# ...

# %%
# prompt: misclassified_df category value count

print("\n잘못 분류된 데이터의 'category' value_counts:")
print(misclassified_df['category'].value_counts(normalize=True))
# Out:
# 잘못 분류된 데이터의 'category' value_counts:
# category
# review         0.620818
# hc3            0.173369
# essay          0.096992
# explanation    0.071308
# dialog         0.037513
# Name: proportion, dtype: float64

# %%
# 원본 데이터에서 test set 샘플만 추출
test_df = df.loc[X_test.index].copy()

# 예측값 추가
test_df["predicted_label"] = y_pred
test_df["true_label"] = y_test.values

# 출력 (예: 앞 5개 행)
print(test_df[["text", "category", "true_label", "predicted_label"]].head())
test_df.info()
# Out:
#                                                      text category  \
# 149713  "Well , little papabusche , let me tell you a ...      hc3
# 11032   This mask was found on Mars and some people th...    essay
# 97926    This is the first time I have ever been able ...   review
# 271     The Advantages of Limiting Car Usage\n\nThere ...    essay
# 12171   Dear Senator,\n\nI think you should get rid of...    essay
#
#         true_label  predicted_label
# 149713           0                0
# 11032            0                0
# 97926            1                1
# 271              1                1
# 12171            0                0
# <class 'pandas.core.frame.DataFrame'>
# Index: 21645 entries, 149713 to 205836
# Data columns (total 96 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             21645 non-null  int64
#  1   text                   21645 non-null  object
# ...

# %%
# prompt: test_df category valuecount

print("\nTest 데이터의 'category' value_counts:")
print(test_df['category'].value_counts(normalize=True))
# Out:
# Test 데이터의 'category' value_counts:
# category
# review         0.384384
# dialog         0.262555
# hc3            0.198614
# essay          0.129776
# explanation    0.024671
# Name: proportion, dtype: float64

# %% [markdown]
# ##베스트파라미터

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report

import pandas as pd

# 데이터 준비
df = pd.read_csv("")

std_cols = [col for col in df.columns if col.endswith('_std')]
range_cols = [col for col in df.columns if col.endswith('_range')]
other_cols = ["mean_emotion_diff", "dominant_change_count", "emotion_entropy", "pos_neg_ratio", "polarity_switches"]

X = df[std_cols + range_cols + other_cols]
y = df["labels"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=100)

# ✅ 베스트 파라미터 적용 모델
best_xgb = XGBClassifier(
    subsample=0.8,
    reg_lambda=1,
    reg_alpha=0.5,
    n_estimators=300,
    min_child_weight=3,
    max_depth=9,
    learning_rate=0.1,
    gamma=0.1,
    colsample_bytree=1.0,
    use_label_encoder=False,
    eval_metric='mlogloss',
    random_state=42
)

# 학습
best_xgb.fit(X_train, y_train)

# 예측
y_pred = best_xgb.predict(X_test)

# 성능 평가
print("\n📌 적용된 베스트 파라미터:")
print(best_xgb.get_params())

print("\n📊 모델 성능 평가:")
print(classification_report(y_test, y_pred))

# 정확도 출력
print("Accuracy :", accuracy_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/training.py:183: UserWarning: [11:10:03] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# 📌 적용된 베스트 파라미터:
# ...

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
# 예측 수행
y_pred = best_xgb.predict(X_test)

# 잘못 예측한 인덱스 찾기
misclassified_indices = X_test.index[y_test != y_pred]
# 원본 df에서 잘못 예측한 샘플만 추출
misclassified_df = df.loc[misclassified_indices].copy()

# 실제 label과 예측 label 컬럼 추가
misclassified_df["true_label"] = y_test.loc[misclassified_indices].values
misclassified_df["predicted_label"] = y_pred[y_test != y_pred]
misclassified_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3614 entries, 181330 to 97807
# Data columns (total 96 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3614 non-null   int64
#  1   text                   3614 non-null   object
#  2   labels                 3614 non-null   int64
#  3   category               3614 non-null   object
#  4   admiration             3614 non-null   object
#  5   amusement              3614 non-null   object
#  6   anger                  3614 non-null   object
#  7   annoyance              3614 non-null   object
#  8   approval               3614 non-null   object
#  9   caring                 3614 non-null   object
#  10  confusion              3614 non-null   object
#  11  curiosity              3614 non-null   object
#  12  desire                 3614 non-null   object
#  13  disappointment         3614 non-null   object
# ...

# %%
# prompt: misclassified_df category value count

print("\n잘못 분류된 데이터의 'category' value_counts:")
print(misclassified_df['category'].value_counts())
# Out:
# 잘못 분류된 데이터의 'category' value_counts:
# category
# review         1837
# hc3             513
# essay           287
# explanation     211
# dialog          111
# Name: count, dtype: int64

# %%
# 원본 데이터에서 test set 샘플만 추출
test_df = df.loc[X_test.index].copy()

# 예측값 추가
test_df["predicted_label"] = y_pred
test_df["true_label"] = y_test.values

# 출력 (예: 앞 5개 행)
print(test_df[["text", "category", "true_label", "predicted_label"]].head())
# Out:
#                                                      text category  \
# 181330  Came here with a reservation via OpenTable (ve...   review
# 113059  This was a good story, but I was hoping it wou...   review
# 254069  Good morning, today we're going to be talking ...   dialog
# 6264    The author presents the reader with the idea t...    essay
# 74693   This movie should have ended as soon as the jo...   review
#
#         true_label  predicted_label
# 181330           0                1
# 113059           0                1
# 254069           1                1
# 6264             0                0
# 74693            0                0

# %%
# prompt: df  category=essay의 labels value count

# Filter the combined dataframe to include only rows where 'category' is 'essay'
df_essay = df_combined[df_combined['category'] == 'essay']

# Get the value counts for the 'labels' column in the filtered dataframe
print(df_essay['labels'].value_counts())
# Out:
# df_combined labels value counts 비율:
# labels
# 0    0.517158
# 1    0.482842
# Name: proportion, dtype: float64

# %%
# prompt: misclassified_df category valuecount

print(misclassified_df['category'].value_counts())
df['category'].value_counts()
# Out:
# category
# review         2431
# hc3             520
# essay           296
# explanation     244
# dialog          123
# Name: count, dtype: int64
# category
# review         123220
# dialog          57324
# hc3             42937
# essay           27181
# explanation      5782
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import xgboost as xgb

# 피처 중요도 시각화 (gain 기준)
xgb.plot_importance(best_xgb, max_num_features=20, importance_type='gain', height=0.6)
plt.title("Top 20 Feature Importances (Gain)")
plt.show()

# %%
import shap

# SHAP explainer 생성
explainer = shap.Explainer(best_xgb, X_train)
shap_values = explainer(X_test)

# 전체 피처 영향도 요약
shap.summary_plot(shap_values, X_test)

# 중요도 순 + 영향 방향 (양/음) 시각화
shap.summary_plot(shap_values, X_test, plot_type="bar")

# 개별 샘플 해석
shap.plots.waterfall(shap_values[0])  # 테스트셋 첫 샘플 해석
# Out:
# 100%|===================| 51278/51289 [48:57<00:00]

# %% [markdown]
# ## 감정 개수 조절해서 진행

# %%
# prompt: df 의 main_emotion value count

df['main_emotion'].value_counts()
# Out:
# main_emotion
# neutral           205614
# admiration         32260
# approval            6671
# love                2875
# joy                 2057
# disappointment      1597
# caring               898
# amusement            848
# disapproval          704
# annoyance            422
# gratitude            394
# sadness              379
# curiosity            305
# confusion            278
# optimism             254
# excitement           198
# fear                 140
# disgust              135
# surprise             129
# desire               127
# realization           86
# remorse               34
# anger                 29
# embarrassment          7
# nervousness            3
# Name: count, dtype: int64

# %%
# prompt: df에서 main_emotion이 'neutral'인 행 173354개 랜덤 삭제

import pandas as pd
# df에서 main_emotion이 'neutral'인 행 173354개 랜덤 삭제
df_neutral = df[df['main_emotion'] == 'neutral']
df_other = df[df['main_emotion'] != 'neutral']

# 'neutral' 데이터프레임에서 173354개 랜덤 샘플링
if len(df_neutral) > 173354:
    df_neutral_sampled = df_neutral.sample(n=len(df_neutral) - 173354, random_state=42)
else:
    df_neutral_sampled = df_neutral # If less than 173354, keep all

# 샘플링된 'neutral' 데이터와 나머지 데이터를 다시 합치기
df = pd.concat([df_neutral_sampled, df_other], ignore_index=True)

# 변경 후 main_emotion별 개수 확인
print(df['main_emotion'].value_counts())
# Out:
# main_emotion
# neutral           32260
# admiration        32260
# approval           6671
# love               2875
# joy                2057
# disappointment     1597
# caring              898
# amusement           848
# disapproval         704
# annoyance           422
# gratitude           394
# sadness             379
# curiosity           305
# confusion           278
# optimism            254
# excitement          198
# fear                140
# disgust             135
# surprise            129
# desire              127
# realization          86
# remorse              34
# anger                29
# embarrassment         7
# nervousness           3
# Name: count, dtype: int64

# %%
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
import pandas as pd

# 데이터 준비 (이전 코드와 동일)
#df = pd.read_csv("combined_data.csv")

std_cols = [col for col in df.columns if col.endswith('_std')]
range_cols = [col for col in df.columns if col.endswith('_range')]
other_cols = ["mean_emotion_diff", "dominant_change_count", "emotion_entropy", "pos_neg_ratio", "polarity_switches"]

X = df[std_cols + range_cols + other_cols]
y = df["labels"]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# XGBoost 기본 모델
xgb = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)

# 하이퍼파라미터 그리드
param_dist = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7, 9],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'gamma': [0, 0.1, 0.5, 1],
    'min_child_weight': [1, 3, 5],
    'reg_alpha': [0, 0.1, 0.5],
    'reg_lambda': [1, 1.5, 2]
}

# RandomizedSearchCV 수행
random_search = RandomizedSearchCV(
    estimator=xgb,
    param_distributions=param_dist,
    n_iter=30,
    scoring='f1_macro',  # 다중 클래스에서 macro F1 score 최적화
    cv=3,
    verbose=2,
    random_state=42,
    n_jobs=-1
)

random_search.fit(X_train, y_train)

# 최적 모델로 예측
best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test)

# 성능 평가
print("Best Parameters:\n", random_search.best_params_)
print("\n📊 최적 모델 성능:\n")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# /usr/local/lib/python3.11/dist-packages/xgboost/training.py:183: UserWarning: [10:33:22] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Best Parameters:
#  {'subsample': 1.0, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_estimators': 300, 'min_child_weight': 1, 'max_depth': 9, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.6}
#
# 📊 최적 모델 성능:
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79      7972
#            1       0.81      0.81      0.81      8646
#
#     accuracy                           0.80     16618
#    macro avg       0.80      0.80      0.80     16618
# weighted avg       0.80      0.80      0.80     16618

# %% [markdown]
# ## 데이터셋 해석|

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256444 entries, 0 to 256443
# Data columns (total 94 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             256444 non-null  int64
#  1   text                   256444 non-null  object
#  2   labels                 256444 non-null  int64
#  3   category               256444 non-null  object
#  4   admiration             256444 non-null  object
#  5   amusement              256444 non-null  object
#  6   anger                  256444 non-null  object
#  7   annoyance              256444 non-null  object
#  8   approval               256444 non-null  object
#  9   caring                 256444 non-null  object
#  10  confusion              256444 non-null  object
#  11  curiosity              256444 non-null  object
#  12  desire                 256444 non-null  object
#  13  disappointment         256444 non-null  object
# ...

# %%
# prompt: labels별 mean_emotion_diff   분포
import seaborn as sns # Import seaborn

import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
sns.violinplot(x='labels', y='mean_emotion_diff', data=df)
plt.title('Distribution of mean_emotion_diff by labels')
plt.xlabel('Labels')
plt.ylabel('mean_emotion_diff')
plt.show()

# %%
# prompt: labels별 dominant_change_count분포

import matplotlib.pyplot as plt
# labels별 dominant_change_count 분포 시각화
plt.figure(figsize=(8, 6))
sns.boxplot(x='labels', y='dominant_change_count', data=df)
plt.title('Labels별 dominant_change_count 분포')
plt.xlabel('Labels')
plt.ylabel('Dominant Change Count')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# prompt: labels별 emotion_entropy    비교

import matplotlib.pyplot as plt
# labels별 emotion_entropy 분포 시각화
plt.figure(figsize=(8, 6))
sns.violinplot(x='labels', y='emotion_entropy', data=df)
plt.title('Labels별 emotion_entropy 분포')
plt.xlabel('Labels')
plt.ylabel('Emotion Entropy')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# prompt: labels 별 pos_neg_ratio 비교

import matplotlib.pyplot as plt
# Labels별 pos_neg_ratio 분포 시각화
plt.figure(figsize=(8, 6))
sns.boxplot(x='labels', y='pos_neg_ratio', data=df)
plt.title('Labels별 pos_neg_ratio 분포')
plt.xlabel('Labels')
plt.ylabel('Positive/Negative Ratio')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# prompt: labels별 polarity_switches분포

import matplotlib.pyplot as plt
# labels별 polarity_switches 분포 시각화
plt.figure(figsize=(8, 6))
sns.boxplot(x='labels', y='polarity_switches', data=df)
plt.title('Labels별 polarity_switches 분포')
plt.xlabel('Labels')
plt.ylabel('Polarity Switches')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# prompt: category value count

print(df['category'].value_counts())
# Out:
# category
# review         123220
# dialog          57324
# hc3             42937
# essay           27181
# explanation      5782
# Name: count, dtype: int64

# %% [markdown]
# ## 데이터셋 해석 2 숫자로

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256444 entries, 0 to 256443
# Data columns (total 94 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             256444 non-null  int64
#  1   text                   256444 non-null  object
#  2   labels                 256444 non-null  int64
#  3   category               256444 non-null  object
#  4   admiration             256444 non-null  object
#  5   amusement              256444 non-null  object
#  6   anger                  256444 non-null  object
#  7   annoyance              256444 non-null  object
#  8   approval               256444 non-null  object
#  9   caring                 256444 non-null  object
#  10  confusion              256444 non-null  object
#  11  curiosity              256444 non-null  object
#  12  desire                 256444 non-null  object
#  13  disappointment         256444 non-null  object
# ...

# %%
# prompt: labels별mean_emotion_diff      통계

# Group by labels and calculate the mean of mean_emotion_diff
mean_emotion_diff_by_label = df.groupby('labels')['mean_emotion_diff'].mean()
print("\nLabels별 mean_emotion_diff 평균:")
print(mean_emotion_diff_by_label)

# Group by labels and calculate the mean of dominant_change_count
dominant_change_count_by_label = df.groupby('labels')['dominant_change_count'].mean()
print("\nLabels별 dominant_change_count 평균:")
print(dominant_change_count_by_label)

# Group by labels and calculate the mean of emotion_entropy
emotion_entropy_by_label = df.groupby('labels')['emotion_entropy'].mean()
print("\nLabels별 emotion_entropy 평균:")
print(emotion_entropy_by_label)

# Group by labels and calculate the mean of pos_neg_ratio
pos_neg_ratio_by_label = df.groupby('labels')['pos_neg_ratio'].mean()
print("\nLabels별 pos_neg_ratio 평균:")
print(pos_neg_ratio_by_label)

# Group by labels and calculate the mean of polarity_switches
polarity_switches_by_label = df.groupby('labels')['polarity_switches'].mean()
print("\nLabels별 polarity_switches 평균:")
print(polarity_switches_by_label)

# Additionally, you might want to see other statistics like median, standard deviation, etc.
print("\nLabels별 mean_emotion_diff 통계:")
print(df.groupby('labels')['mean_emotion_diff'].describe())

print("\nLabels별 dominant_change_count 통계:")
print(df.groupby('labels')['dominant_change_count'].describe())

print("\nLabels별 emotion_entropy 통계:")
print(df.groupby('labels')['emotion_entropy'].describe())

print("\nLabels별 pos_neg_ratio 통계:")
print(df.groupby('labels')['pos_neg_ratio'].describe())

print("\nLabels별 polarity_switches 통계:")
print(df.groupby('labels')['polarity_switches'].describe())
# Out:
# Labels별 mean_emotion_diff 평균:
# labels
# 0    0.647552
# 1    0.695263
# Name: mean_emotion_diff, dtype: float64
#
# Labels별 dominant_change_count 평균:
# labels
# 0     6.325255
# 1    10.364023
# Name: dominant_change_count, dtype: float64
#
# Labels별 emotion_entropy 평균:
# labels
# 0    2.600744
# 1    2.700076
# Name: emotion_entropy, dtype: float64
#
# Labels별 pos_neg_ratio 평균:
# labels
# 0    5.272648
# 1    7.546147
# Name: pos_neg_ratio, dtype: float64
#
# Labels별 polarity_switches 평균:
# labels
# 0    0.310567
# 1    0.199730
# Name: polarity_switches, dtype: float64
#
# Labels별 mean_emotion_diff 통계:
#            count      mean       std       min       25%       50%       75%  \
# labels
# 0       132622.0  0.647552  0.236812  0.002673  0.489611  0.663453  0.813049
# 1       123822.0  0.695263  0.252233  0.000112  0.515795  0.768792  0.884447
#
#              max
# labels
# 0       1.531379
# 1       1.564321
#
# Labels별 dominant_change_count 통계:
# ...

# %% [markdown]
# ## 카테고리 더미변수

# %%
# prompt: google drive 에서 파일 불러오기
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

# Mount your Google Drive and replace 'YourFileName.csv' with the actual file path in your Drive

# 데이터 불러오기
# Replace 'combined_data.csv' with the path where you saved the combined file in your Drive
df = pd.read_csv("/content/drive/MyDrive/combined_data.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# prompt: df의 category열 더미변수 처리

import pandas as pd
# 'category' 열을 더미 변수화
df = pd.get_dummies(df, columns=['category'], drop_first=True)

# 변경 후 데이터프레임 정보 확인 (새로운 더미 변수 컬럼 확인)
print("\n더미 변수 처리 후 df 정보:")
df.info()

# 더미 변수 처리 결과의 일부 확인
print("\n더미 변수 처리 후 df head():")
print(df.head())
# Out:
# 더미 변수 처리 후 df 정보:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256444 entries, 0 to 256443
# Data columns (total 97 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             256444 non-null  int64
#  1   text                   256444 non-null  object
#  2   labels                 256444 non-null  int64
#  3   admiration             256444 non-null  object
#  4   amusement              256444 non-null  object
#  5   anger                  256444 non-null  object
#  6   annoyance              256444 non-null  object
#  7   approval               256444 non-null  object
#  8   caring                 256444 non-null  object
#  9   confusion              256444 non-null  object
#  10  curiosity              256444 non-null  object
#  11  desire                 256444 non-null  object
#  12  disappointment         256444 non-null  object
#  13  disapproval            256444 non-null  object
# ...

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report

import pandas as pd

# 데이터 준비
#df = pd.read_csv("plus_feature_file_cleaned.csv")

std_cols = [col for col in df.columns if col.endswith('_std')]
range_cols = [col for col in df.columns if col.endswith('_range')]
other_cols = ["mean_emotion_diff", "dominant_change_count", "emotion_entropy", "pos_neg_ratio", "polarity_switches"]
category_cols = ["category_essay", "category_explanation", "category_hc3", "category_review"]
X = df[std_cols + range_cols + other_cols+ category_cols]
y = df["labels"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=100)

# ✅ 베스트 파라미터 적용 모델
best_xgb = XGBClassifier(
    subsample=0.8,
    reg_lambda=1,
    reg_alpha=0.5,
    n_estimators=300,
    min_child_weight=3,
    max_depth=9,
    learning_rate=0.1,
    gamma=0.1,
    colsample_bytree=1.0,
    use_label_encoder=False,
    eval_metric='mlogloss',
    random_state=42
)

# 학습
best_xgb.fit(X_train, y_train)

# 예측
y_pred = best_xgb.predict(X_test)

# 성능 평가
print("\n📌 적용된 베스트 파라미터:")
print(best_xgb.get_params())

print("\n📊 모델 성능 평가:")
print(classification_report(y_test, y_pred))

# 정확도 출력
print("Accuracy :", accuracy_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [06:26:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 📌 적용된 베스트 파라미터:
# ...

# %%
# prompt: df의 category열 더미변수 처리

import pandas as pd
# 'category' 열을 더미 변수화
df_combined_filtered = pd.get_dummies(df_combined_filtered, columns=['category'], drop_first=True)

# 변경 후 데이터프레임 정보 확인 (새로운 더미 변수 컬럼 확인)
print("\n더미 변수 처리 후 df 정보:")
df_combined_filtered.info()

# 더미 변수 처리 결과의 일부 확인
print("\n더미 변수 처리 후 df head():")
print(df_combined_filtered.head())
# Out:
# 더미 변수 처리 후 df 정보:
# <class 'pandas.core.frame.DataFrame'>
# Index: 216444 entries, 0 to 256443
# Data columns (total 97 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             216444 non-null  int64
#  1   text                   216444 non-null  object
#  2   labels                 216444 non-null  int64
#  3   admiration             216444 non-null  object
#  4   amusement              216444 non-null  object
#  5   anger                  216444 non-null  object
#  6   annoyance              216444 non-null  object
#  7   approval               216444 non-null  object
#  8   caring                 216444 non-null  object
#  9   confusion              216444 non-null  object
#  10  curiosity              216444 non-null  object
#  11  desire                 216444 non-null  object
#  12  disappointment         216444 non-null  object
#  13  disapproval            216444 non-null  object
# ...

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report

import pandas as pd

# 데이터 준비
#df = pd.read_csv("plus_feature_file_cleaned.csv")

std_cols = [col for col in df_combined_filtered.columns if col.endswith('_std')]
range_cols = [col for col in df_combined_filtered.columns if col.endswith('_range')]
other_cols = ["mean_emotion_diff", "dominant_change_count", "emotion_entropy", "pos_neg_ratio", "polarity_switches"]
category_cols = ["category_essay", "category_explanation", "category_hc3", "category_review"]
X = df_combined_filtered[std_cols + range_cols + other_cols+ category_cols]
y = df_combined_filtered["labels"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=100)

# ✅ 베스트 파라미터 적용 모델
best_xgb = XGBClassifier(
    subsample=0.8,
    reg_lambda=1,
    reg_alpha=0.5,
    n_estimators=300,
    min_child_weight=3,
    max_depth=9,
    learning_rate=0.1,
    gamma=0.1,
    colsample_bytree=1.0,
    use_label_encoder=False,
    eval_metric='mlogloss',
    random_state=42
)

# 학습
best_xgb.fit(X_train, y_train)

# 예측
y_pred = best_xgb.predict(X_test)

# 성능 평가
print("\n📌 적용된 베스트 파라미터:")
print(best_xgb.get_params())

print("\n📊 모델 성능 평가:")
print(classification_report(y_test, y_pred))

# 정확도 출력
print("Accuracy :", accuracy_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [06:30:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 📌 적용된 베스트 파라미터:
# ...

# %% [markdown]
# ## 랜덤포레스트

# %%
df = pd.read_csv("/content/drive/MyDrive/dialog_category_final.csv")

# %%
# prompt: labels valuecount

print(df['labels'].value_counts())
# Out:
# labels
# 1    47234
# 0    46165
# Name: count, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
import pandas as pd

# 데이터 준비

std_cols = [col for col in df.columns if col.endswith('_std')]
range_cols = [col for col in df.columns if col.endswith('_range')]
other_cols = ["mean_emotion_diff", "dominant_change_count", "emotion_entropy", "pos_neg_ratio", "polarity_switches"]

X = df[std_cols + range_cols + other_cols]
y = df["labels"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=100)

# ✅ 랜덤 포레스트 모델
rf_model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
rf_model.fit(X_train, y_train)

# 예측
y_pred_rf = rf_model.predict(X_test)

# 평가
print("\n📊 RandomForestClassifier 성능 평가:")
print(classification_report(y_test, y_pred_rf))
print("Accuracy :", accuracy_score(y_test, y_pred_rf))
print("F1 Score :", f1_score(y_test, y_pred_rf))
print("Precision:", precision_score(y_test, y_pred_rf))
print("Recall   :", recall_score(y_test, y_pred_rf))
# Out:
# 📊 RandomForestClassifier 성능 평가:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.98      4612
#            1       0.96      0.99      0.98      4728
#
#     accuracy                           0.98      9340
#    macro avg       0.98      0.98      0.98      9340
# weighted avg       0.98      0.98      0.98      9340
#
# Accuracy : 0.9775160599571735
# F1 Score : 0.978134110787172
# Precision: 0.9632895816242822
# Recall   : 0.9934433164128595

# %%
# prompt: 중요도 추출

import matplotlib.pyplot as plt
import xgboost as xgb # Import the xgboost library

# XGBoost 피처 중요도 시각화 (gain 기준)
xgb.plot_importance(best_xgb, max_num_features=20, importance_type='gain', height=0.6) # Use xgb.plot_importance
plt.title("Top 20 Feature Importances (Gain)")
plt.show()

# Ensure shap is installed
# !pip install shap

import shap

# SHAP explainer 생성
# Assuming best_xgb and X_train are defined from previous cells
explainer = shap.Explainer(best_xgb, X_train)
shap_values = explainer(X_test) # Assuming X_test is defined

# 전체 피처 영향도 요약 (SHAP value 기준)
shap.summary_plot(shap_values, X_test)

# 전체 피처 영향도 요약 (SHAP value 평균 절대값 기준 막대 그래프)
shap.summary_plot(shap_values, X_test, plot_type="bar")

# 개별 샘플 해석 (첫 번째 테스트 샘플)
shap.plots.waterfall(shap_values[0])
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 16.3 MB/s eta 0:00:00
# ...
#  10%|==                  | 908/9340 [00:33<05:06]

# %%
# prompt: combined_fianl.csv category별 labels valuecount

import pandas as pd
# 'combined_fianl.csv' 파일에서 데이터 불러오기
# 이 코드는 파일 이름이 'combined_fianl.csv'라고 가정합니다.
# 실제 파일 경로와 이름에 맞게 수정해주세요.
try:
    df_combined_final = pd.read_csv("combined_fianl.csv")
    print("'combined_fianl.csv' 파일을 성공적으로 불러왔습니다.")

    # category별 labels valuecount 계산
    category_labels_counts = df_combined_final.groupby('category')['labels'].value_counts()

    print("\ncombined_fianl.csv 파일의 카테고리별 labels value counts:")
category_labels_counts
# Out:
#   File "<ipython-input-2-3622703947>", line 15
#     category_labels_counts
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %%
category_labels_counts
# Out:
# category     labels
# dialog       1         47234
#              0         35620
# essay        0         16004
#              1         11177
# explanation  0          3341
#              1          2441
# hc3          1         22950
#              0         19987
# review       0         83200
#              1         40020
# 대화문          0         10545
# Name: count, dtype: int64

# %%
# prompt: df_combined_final에서 category='review'인행 label별로 각각 10000개만 남기고 삭제

import pandas as pd
# df_combined_final에서 category='review'인 행 필터링
df_review = df_combined_final[df_combined_final['category'] == 'review'].copy()

# review 카테고리 내에서 label별로 데이터 분리
df_review_0 = df_review[df_review['labels'] == 0]
df_review_1 = df_review[df_review['labels'] == 1]

# 각 label별로 10000개 샘플링
n_samples = 10000

# label 0에서 10000개 샘플링 또는 전체 사용
if len(df_review_0) > n_samples:
    df_review_0_sampled = df_review_0.sample(n=n_samples, random_state=42)
else:
    df_review_0_sampled = df_review_0.copy()
    print(f"category='review', label=0 데이터가 {n_samples}개보다 적습니다 ({len(df_review_0)}개). 전체를 사용합니다.")

# label 1에서 10000개 샘플링 또는 전체 사용
if len(df_review_1) > n_samples:
    df_review_1_sampled = df_review_1.sample(n=n_samples, random_state=42)
else:
    df_review_1_sampled = df_review_1.copy()
    print(f"category='review', label=1 데이터가 {n_samples}개보다 적습니다 ({len(df_review_1)}개). 전체를 사용합니다.")

# 샘플링된 review 데이터 합치기
df_review_sampled = pd.concat([df_review_0_sampled, df_review_1_sampled], ignore_index=True)

# review 카테고리가 아닌 나머지 데이터 필터링
df_other_categories = df_combined_final[df_combined_final['category'] != 'review'].copy()

# 샘플링된 review 데이터와 나머지 카테고리 데이터 다시 합치기
df_combined_final_sampled = pd.concat([df_review_sampled, df_other_categories], ignore_index=True)

print("\nCategory가 'review'인 행을 label별로 10000개씩 샘플링한 후의 데이터 정보:")
df_combined_final_sampled.info()

print("\n샘플링 후 category별 value counts:")
df_combined_final_sampled['category'].value_counts()

print("\n샘플링 후 category='review'의 label별 value counts:")
df_combined_final_sampled[df_combined_final_sampled['category'] == 'review']['labels'].value_counts()

print("\n샘플링 후 전체 label value counts:")
print(df_combined_final_sampled['labels'].value_counts())

# 결과를 새로운 CSV 파일로 저장 (선택 사항)
# df_combined_final_sampled.to_csv('/content/drive/MyDrive/combined_final_review_sampled.csv', index=False)
# print("\n샘플링된 데이터가 'combined_final_review_sampled.csv' 파일로 저장되었습니다.")
# Out:
# Category가 'review'인 행을 label별로 10000개씩 샘플링한 후의 데이터 정보:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189299 entries, 0 to 189298
# Data columns (total 95 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0.1           189299 non-null  int64
#  1   Unnamed: 0             153224 non-null  float64
#  2   text                   189299 non-null  object
#  3   labels                 189299 non-null  int64
#  4   category               189299 non-null  object
#  5   admiration             189299 non-null  object
#  6   amusement              189299 non-null  object
#  7   anger                  189299 non-null  object
#  8   annoyance              189299 non-null  object
#  9   approval               189299 non-null  object
#  10  caring                 189299 non-null  object
#  11  confusion              189299 non-null  object
#  12  curiosity              189299 non-null  object
# ...

# %%
# prompt: df_combined_final_sampled의 category별 labels valuecount

print("df_combined_final_sampled의 category별 labels valuecount:")
print(df_combined_final_sampled.groupby('category')['labels'].value_counts())
# Out:
# df_combined_final_sampled의 category별 labels valuecount:
# category     labels
# dialog       1         47234
#              0         35620
# essay        0         16004
#              1         11177
# explanation  0          3341
#              1          2441
# hc3          1         22950
#              0         19987
# review       0         10000
#              1         10000
# 대화문          0         10545
# Name: count, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
import pandas as pd
df = df_combined_final_sampled
# 데이터 준비

std_cols = [col for col in df.columns if col.endswith('_std')]
range_cols = [col for col in df.columns if col.endswith('_range')]
other_cols = ["mean_emotion_diff", "dominant_change_count", "emotion_entropy", "pos_neg_ratio", "polarity_switches"]

X = df[std_cols + range_cols + other_cols]
y = df["labels"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=100)

# ✅ 랜덤 포레스트 모델
rf_model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
rf_model.fit(X_train, y_train)

# 예측
y_pred_rf = rf_model.predict(X_test)

# 평가
print("\n📊 RandomForestClassifier 성능 평가:")
print(classification_report(y_test, y_pred_rf))
print("Accuracy :", accuracy_score(y_test, y_pred_rf))
print("F1 Score :", f1_score(y_test, y_pred_rf))
print("Precision:", precision_score(y_test, y_pred_rf))
print("Recall   :", recall_score(y_test, y_pred_rf))
# Out:
# 📊 RandomForestClassifier 성능 평가:
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87      9531
#            1       0.88      0.84      0.86      9399
#
#     accuracy                           0.86     18930
#    macro avg       0.86      0.86      0.86     18930
# weighted avg       0.86      0.86      0.86     18930
#
# Accuracy : 0.863391442155309
# F1 Score : 0.859272964736613
# Precision: 0.8794697560432215
# Recall   : 0.8399829769124375

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report

import pandas as pd

# 데이터 준비
#df = pd.read_csv("plus_feature_file_cleaned.csv")
std_cols = [col for col in df.columns if col.endswith('_std')]
range_cols = [col for col in df.columns if col.endswith('_range')]
other_cols = ["mean_emotion_diff", "dominant_change_count", "emotion_entropy", "pos_neg_ratio", "polarity_switches"]
X = df[std_cols + range_cols + other_cols]
y = df["labels"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=100)

# ✅ 베스트 파라미터 적용 모델
best_xgb = XGBClassifier(
    subsample=0.8,
    reg_lambda=1,
    reg_alpha=0.5,
    n_estimators=300,
    min_child_weight=3,
    max_depth=9,
    learning_rate=0.1,
    gamma=0.1,
    colsample_bytree=1.0,
    use_label_encoder=False,
    eval_metric='mlogloss',
    random_state=42
)

# 학습
best_xgb.fit(X_train, y_train)

# 예측
y_pred = best_xgb.predict(X_test)

# 성능 평가
print("\n📌 적용된 베스트 파라미터:")
print(best_xgb.get_params())

print("\n📊 모델 성능 평가:")
print(classification_report(y_test, y_pred))

# 정확도 출력
print("Accuracy :", accuracy_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/training.py:183: UserWarning: [12:05:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# 📌 적용된 베스트 파라미터:
# ...

# %%
# prompt: df_combined_final_sampled에서 category=review인 행 삭제

df_combined_final_sampled = df_combined_final_sampled[df_combined_final_sampled['category'] != 'review'].copy()

print("\n'category'가 'review'인 행 삭제 후 데이터 정보:")
df_combined_final_sampled.info()

print("\n삭제 후 category별 value counts:")
print(df_combined_final_sampled['category'].value_counts())

print("\n삭제 후 전체 label value counts:")
print(df_combined_final_sampled['labels'].value_counts())
# Out:
# 'category'가 'review'인 행 삭제 후 데이터 정보:
# <class 'pandas.core.frame.DataFrame'>
# Index: 169299 entries, 20000 to 189298
# Data columns (total 95 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0.1           169299 non-null  int64
#  1   Unnamed: 0             133224 non-null  float64
#  2   text                   169299 non-null  object
#  3   labels                 169299 non-null  int64
#  4   category               169299 non-null  object
#  5   admiration             169299 non-null  object
#  6   amusement              169299 non-null  object
#  7   anger                  169299 non-null  object
#  8   annoyance              169299 non-null  object
#  9   approval               169299 non-null  object
#  10  caring                 169299 non-null  object
#  11  confusion              169299 non-null  object
#  12  curiosity              169299 non-null  object
# ...

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report

import pandas as pd
df = df_combined_final_sampled
# 데이터 준비
#df = pd.read_csv("plus_feature_file_cleaned.csv")
std_cols = [col for col in df.columns if col.endswith('_std')]
range_cols = [col for col in df.columns if col.endswith('_range')]
other_cols = ["mean_emotion_diff", "dominant_change_count", "emotion_entropy", "pos_neg_ratio", "polarity_switches"]
X = df[std_cols + range_cols + other_cols]
y = df["labels"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=100)

# ✅ 베스트 파라미터 적용 모델
best_xgb = XGBClassifier(
    subsample=0.8,
    reg_lambda=1,
    reg_alpha=0.5,
    n_estimators=300,
    min_child_weight=3,
    max_depth=9,
    learning_rate=0.1,
    gamma=0.1,
    colsample_bytree=1.0,
    use_label_encoder=False,
    eval_metric='mlogloss',
    random_state=42
)

# 학습
best_xgb.fit(X_train, y_train)

# 예측
y_pred = best_xgb.predict(X_test)

# 성능 평가
print("\n📌 적용된 베스트 파라미터:")
print(best_xgb.get_params())

print("\n📊 모델 성능 평가:")
print(classification_report(y_test, y_pred))

# 정확도 출력
print("Accuracy :", accuracy_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/training.py:183: UserWarning: [12:07:17] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# 📌 적용된 베스트 파라미터:
# ...

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report

import pandas as pd
df = df_combined_final_sampled
# 데이터 준비
#df = pd.read_csv("plus_feature_file_cleaned.csv")
std_cols = [col for col in df.columns if col.endswith('_std')]
range_cols = [col for col in df.columns if col.endswith('_range')]
other_cols = ["mean_emotion_diff", "dominant_change_count", "emotion_entropy", "pos_neg_ratio", "polarity_switches"]
X = df[std_cols + range_cols + other_cols]
y = df["labels"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# ✅ 베스트 파라미터 적용 모델
best_xgb = XGBClassifier(
    subsample=0.8,
    reg_lambda=1,
    reg_alpha=0.5,
    n_estimators=300,
    min_child_weight=3,
    max_depth=9,
    learning_rate=0.1,
    gamma=0.1,
    colsample_bytree=1.0,
    use_label_encoder=False,
    eval_metric='mlogloss',
    random_state=42
)

# 학습
best_xgb.fit(X_train, y_train)

# 예측
y_pred = best_xgb.predict(X_test)

# 성능 평가
print("\n📌 적용된 베스트 파라미터:")
print(best_xgb.get_params())

print("\n📊 모델 성능 평가:")
print(classification_report(y_test, y_pred))

# 정확도 출력
print("Accuracy :", accuracy_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/training.py:183: UserWarning: [12:07:31] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# 📌 적용된 베스트 파라미터:
# ...

# %%
# prompt: df_combined_final_sampled labels valuecount

print(df_combined_final_sampled['labels'].value_counts())
# Out:
# labels
# 0    85497
# 1    83802
# Name: count, dtype: int64

# %%
# prompt: 카테고리별 labels valuecount

print("\ndf_combined_final_sampled의 category별 labels valuecount:")
df_combined_final_sampled.groupby('category')['labels'].value_counts()
# Out:
# df_combined_final_sampled의 category별 labels valuecount:
# category     labels
# dialog       1         47234
#              0         35620
# essay        0         16004
#              1         11177
# explanation  0          3341
#              1          2441
# hc3          1         22950
#              0         19987
# 대화문          0         10545
# Name: count, dtype: int64
